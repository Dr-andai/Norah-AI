# %%
from nilearn.plotting import plot_stat_map
from nilearn import datasets
from nilearn import image

# %%
bg_img = datasets.load_mni152_template(resolution=1)

# %%
img = datasets.load_mni152_template(1)

# %%
# Plot the overlay on the backgeround
plot_stat_map(img,
		bg_img=bg_img,
		threshold=1,
		cut_coords = [0, 0, 0],
		colorbar=True,
		resampling_interpolation='continuous',
		draw_cross=False)
# Out:
# C:\Users\david.andai\AppData\Local\Temp\ipykernel_30132\250689013.py:2: UserWarning: empty mask
#   plot_stat_map(img,
